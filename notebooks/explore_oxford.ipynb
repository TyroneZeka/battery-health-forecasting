# %%
import scipy.io as sio
import os

# Directory with Oxford data
data_dir = '../data/Oxford/'
file_path = os.path.join(data_dir, 'Oxford_Battery_Degradation_Dataset_1.mat')

if not os.path.exists(file_path):
    raise FileNotFoundError(f"Oxford dataset file not found at {file_path}. Please ensure it’s in {data_dir}.")

# Load the .mat file
mat_data = sio.loadmat(file_path)

# Print all top-level keys to identify the correct one
print("Top-level keys in Oxford_Battery_Degradation_Dataset_1.mat:")
for key in mat_data.keys():
    print(key)

# Optionally, inspect a key's structure (e.g., first key)
if mat_data.keys():
    sample_key = list(mat_data.keys())[0]
    print(f"\nStructure of key '{sample_key}':")
    print(mat_data[sample_key])
# Out:
# Top-level keys in Oxford_Battery_Degradation_Dataset_1.mat:
# __header__
# __version__
# __globals__
# Cell1
# Cell2
# Cell3
# Cell4
# Cell5
# Cell6
# Cell7
# Cell8
#
# Structure of key '__header__':
# b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon Jun 05 11:16:25 2017'

# %%
import os
import scipy.io as sio
import numpy as np
import pandas as pd

# Directory with Oxford data (create if needed)
data_dir = '../data/Oxford/'
os.makedirs(data_dir, exist_ok=True)

# Load Oxford_Battery_Degradation_Dataset_1.mat
file_path = os.path.join(data_dir, 'Oxford_Battery_Degradation_Dataset_1.mat')
if not os.path.exists(file_path):
    raise FileNotFoundError(f"Oxford dataset file not found at {file_path}. Please ensure it’s in {data_dir}.")

mat_data = sio.loadmat(file_path)

# Process each cell (1-8, using 'Cell1' to 'Cell8' as top-level keys)
for cell_id in range(1, 9):  # Cells 1 to 8
    cell_key = f'Cell{cell_id}'  # Match the exact key format
    if cell_key not in mat_data.keys():
        print(f"Warning: {cell_key} not found in dataset. Skipping.")
        continue

    cell_data = mat_data[cell_key][0, 0]  # Access cell data directly
    print(f"\nProcessing {cell_key}...")

    # Extract characterization cycles (e.g., cyc0100, cyc0200, etc.)
    cycles = []
    capacities = []  # From 1-C discharge or charge in Ah
    voltages = []
    currents = []
    temps = []
    soh = []  # State of Health (%)

    # Get all cycle keys (e.g., 'cyc0100', 'cyc0200', etc.)
    cycle_keys = [key for key in cell_data.dtype.names if key.startswith('cyc')]
    cycle_keys.sort()  # Sort to ensure chronological order
    print(f"Found cycle keys: {cycle_keys}")

    # Get initial capacity from cyc0000 (1-C discharge)
    initial_capacity = None
    for cycle_key in cycle_keys:
        if cycle_key == 'cyc0000':
            cycle_data = cell_data[cycle_key][0, 0]
            if 'C1dc' in cycle_data.dtype.names:
                discharge = cycle_data['C1dc'][0, 0]
                if 'q' in discharge.dtype.names:
                    initial_capacity_mah = abs(discharge['q'][-1])  # Last value in mAh
                    # Extract scalar from NumPy array
                    initial_capacity_mah_scalar = initial_capacity_mah.item() if hasattr(initial_capacity_mah, 'item') else initial_capacity_mah[0]
                    initial_capacity = initial_capacity_mah_scalar / 1000  # Convert to Ah
                    print(f"Initial capacity for {cell_key}: {initial_capacity:.3f} Ah")
                    break

    if initial_capacity is None:
        print(f"No initial capacity found for {cell_key}, using default 0.740 Ah")
        initial_capacity = 0.740  # Default per README

    for cycle_key in cycle_keys:
        print(f"\nProcessing cycle {cycle_key}...")
        cycle_data = cell_data[cycle_key][0, 0]
        
        # Debug: Print cycle data structure
        print(f"Cycle data keys: {cycle_data.dtype.names}")

        # Try 1-C discharge (C1dc) first, then 1-C charge (C1ch) if needed
        discharge_key = 'C1dc'  # 1-C discharge
        if discharge_key in cycle_data.dtype.names:
            discharge = cycle_data[discharge_key][0, 0]
            print(f"Discharge data keys: {discharge.dtype.names}")
            if 'q' in discharge.dtype.names:  # 'q' is charge in mAh
                capacity_mah = discharge['q'][-1]  # Last value is total capacity (mAh)
                print(f"Raw capacity (mAh): {capacity_mah}, Shape: {capacity_mah.shape if hasattr(capacity_mah, 'shape') else 'N/A'}")
                # Extract scalar, handle empty or malformed arrays, take absolute for discharge
                capacity_mah_scalar = abs(capacity_mah.item()) if hasattr(capacity_mah, 'item') and capacity_mah.size > 0 else \
                                    abs(capacity_mah[0]) if capacity_mah.size > 0 else np.nan
                capacity_ah = capacity_mah_scalar / 1000  # Convert to Ah
                capacities.append(capacity_ah)
                # Calculate SoH (%)
                soh_value = (capacity_ah / initial_capacity) * 100 if not np.isnan(capacity_ah) else np.nan
                soh.append(soh_value)
            else:
                capacities.append(np.nan)  # No capacity data
                soh.append(np.nan)
                print("No 'q' field in discharge data, setting capacity and SoH to NaN")
            # Extract features, handling NumPy arrays
            if 'v' in discharge.dtype.names and discharge['v'].size > 0:
                voltage = discharge['v'][0]
                voltage_scalar = voltage.item() if hasattr(voltage, 'item') else np.mean(voltage) if voltage.size > 0 else np.nan
                voltages.append(voltage_scalar)
            else:
                voltages.append(np.nan)
                print("No valid voltage data in discharge, setting to NaN")
            
            if 'q' in discharge.dtype.names and 't' in discharge.dtype.names:
                charge = discharge['q']
                print(f"Charge shape: {charge.shape if hasattr(charge, 'shape') else 'N/A'}")
                time = discharge['t']
                print(f"Time shape: {time.shape if hasattr(time, 'shape') else 'N/A'}")
                print(f"Time values (first 5): {time[:5] if time.size > 0 else 'N/A'}")  # Debug time values
                if charge.size > 0 and time.size > 1:
                    # Convert MATLAB datenum (days) to seconds for time_diff
                    time_clean = np.unique(time[~np.isnan(time)])  # Remove NaN and duplicates
                    if len(time_clean) > 1:
                        # Time difference in days, convert to seconds (86400 seconds/day)
                        time_diff_days = np.diff(time_clean)[0]
                        time_diff_seconds = time_diff_days * 86400  # Convert days to seconds
                        if time_diff_seconds > 0:  # Ensure positive time difference
                            current_mah = charge / time_diff_seconds  # Current in mA (mAh/s)
                            # Use mean for multi-element array, adjust for units
                            current_scalar = np.mean(current_mah) if current_mah.size > 0 and not np.isnan(current_mah).any() else np.nan
                            current_scalar = current_scalar / 1000  # Convert mA to A
                        else:
                            current_scalar = np.nan
                            print("Time difference is zero or negative after conversion, setting current to NaN")
                    else:
                        current_scalar = np.nan
                        print("Insufficient unique time points after cleaning, setting current to NaN")
                else:
                    current_scalar = np.nan
                    print("Insufficient charge or time data, setting current to NaN")
                currents.append(-current_scalar)  # Keep negative for discharge, convert mA to A
            else:
                currents.append(np.nan)
                print("No valid charge or time data for current calculation, setting to NaN")
            
            if 'T' in discharge.dtype.names and discharge['T'].size > 0:
                temp = discharge['T'][0]
                temp_scalar = temp.item() if hasattr(temp, 'item') else np.mean(temp) if temp.size > 0 else np.nan
                temps.append(temp_scalar)
            else:
                temps.append(np.nan)
                print("No valid temperature data in discharge, setting to NaN")
        else:
            # Fall back to 1-C charge (C1ch) if discharge data is missing
            charge_key = 'C1ch'
            if charge_key in cycle_data.dtype.names:
                charge = cycle_data[charge_key][0, 0]
                print(f"Charge data keys: {charge.dtype.names}")
                if 'q' in charge.dtype.names:
                    capacity_mah = charge['q'][-1]  # Last value is total capacity (mAh)
                    print(f"Raw capacity (mAh): {capacity_mah}, Shape: {capacity_mah.shape if hasattr(capacity_mah, 'shape') else 'N/A'}")
                    capacity_mah_scalar = abs(capacity_mah.item()) if hasattr(capacity_mah, 'item') and capacity_mah.size > 0 else \
                                        abs(capacity_mah[0]) if capacity_mah.size > 0 else np.nan
                    capacity_ah = capacity_mah_scalar / 1000  # Convert to Ah
                    capacities.append(capacity_ah)
                    # Calculate SoH (%)
                    soh_value = (capacity_ah / initial_capacity) * 100 if not np.isnan(capacity_ah) else np.nan
                    soh.append(soh_value)
                else:
                    capacities.append(np.nan)
                    soh.append(np.nan)
                    print("No 'q' field in charge data, setting capacity and SoH to NaN")
                if 'v' in charge.dtype.names and charge['v'].size > 0:
                    voltage = charge['v'][0]
                    voltage_scalar = voltage.item() if hasattr(voltage, 'item') else np.mean(voltage) if voltage.size > 0 else np.nan
                    voltages.append(voltage_scalar)
                else:
                    voltages.append(np.nan)
                    print("No valid voltage data in charge, setting to NaN")
                
                if 'q' in charge.dtype.names and 't' in charge.dtype.names:
                    charge = charge['q']
                    print(f"Charge shape: {charge.shape if hasattr(charge, 'shape') else 'N/A'}")
                    time = charge['t']
                    print(f"Time shape: {time.shape if hasattr(time, 'shape') else 'N/A'}")
                    print(f"Time values (first 5): {time[:5] if time.size > 0 else 'N/A'}")  # Debug time values
                    if charge.size > 0 and time.size > 1:
                        # Convert MATLAB datenum (days) to seconds for time_diff
                        time_clean = np.unique(time[~np.isnan(time)])  # Remove NaN and duplicates
                        if len(time_clean) > 1:
                            # Time difference in days, convert to seconds (86400 seconds/day)
                            time_diff_days = np.diff(time_clean)[0]
                            time_diff_seconds = time_diff_days * 86400  # Convert days to seconds
                            if time_diff_seconds > 0:  # Ensure positive time difference
                                current_mah = charge / time_diff_seconds  # Current in mA (mAh/s)
                                # Use mean for multi-element array, adjust for units
                                current_scalar = np.mean(current_mah) if current_mah.size > 0 and not np.isnan(current_mah).any() else np.nan
                                current_scalar = current_scalar / 1000  # Convert mA to A
                            else:
                                current_scalar = np.nan
                                print("Time difference is zero or negative after conversion, setting current to NaN")
                        else:
                            current_scalar = np.nan
                            print("Insufficient unique time points after cleaning, setting current to NaN")
                    else:
                        current_scalar = np.nan
                        print("Insufficient charge or time data, setting current to NaN")
                    currents.append(current_scalar)  # Keep positive for charge, convert mA to A
                else:
                    currents.append(np.nan)
                    print("No valid charge or time data for current calculation in charge, setting to NaN")
                
                if 'T' in charge.dtype.names and charge['T'].size > 0:
                    temp = charge['T'][0]
                    temp_scalar = temp.item() if hasattr(temp, 'item') else np.mean(temp) if temp.size > 0 else np.nan
                    temps.append(temp_scalar)
                else:
                    temps.append(np.nan)
                    print("No valid temperature data in charge, setting to NaN")
            else:
                capacities.append(np.nan)
                soh.append(np.nan)
                voltages.append(np.nan)
                currents.append(np.nan)
                temps.append(np.nan)
                print(f"Warning: No charge or discharge data for {cycle_key} in {cell_key}")

        # Cycle number (e.g., 100, 200, etc.) from cycle_key (e.g., 'cyc0100' → 100)
        cycle_num = (int(cycle_key.replace('cyc', '')) / 100) + 1  # Convert to 1-based cycle number (e.g., 100 → 2, 200 → 3)
        cycles.append(cycle_num)

        # Debug: Check lengths after each cycle
        print(f"Current lengths - Cycles: {len(cycles)}, Capacities: {len(capacities)}, "
              f"Voltages: {len(voltages)}, Currents: {len(currents)}, Temps: {len(temps)}, SoH: {len(soh)}")

    # Verify all lists have the same length before creating DataFrame
    lengths = [len(cycles), len(capacities), len(voltages), len(currents), len(temps), len(soh)]
    if len(set(lengths)) > 1:
        print(f"Warning: Mismatched lengths - {dict(zip(['cycles', 'capacities', 'voltages', 'currents', 'temps', 'soh'], lengths))}")
        # Find and pad or truncate to match the longest list with NaN
        max_length = max(lengths)
        for lst, name in zip([cycles, capacities, voltages, currents, temps, soh], 
                            ['cycles', 'capacities', 'voltages', 'currents', 'temps', 'soh']):
            if len(lst) < max_length:
                print(f"Padding {name} with NaN to match length {max_length}")
                lst.extend([np.nan] * (max_length - len(lst)))

    # Calculate RUL (using 80% SoH threshold, 0.592 Ah for 0.740 Ah initial)
    failure_threshold = 0.592  # 80% of 0.740 Ah (adjust to 0.518 Ah for 70% if needed)
    failure_cycle = -1
    valid_capacities = [c for c in capacities if not np.isnan(c)]  # Ignore NaN
    valid_cycles = [c for c, cap in zip(cycles, capacities) if not np.isnan(cap)]

    if valid_capacities:
        # Extract scalar values for comparison, handle negative values
        valid_capacities_scalar = [abs(c.item()) if hasattr(c, 'item') and not np.isnan(c) else abs(c) for c in valid_capacities]
        for i, cap in enumerate(valid_capacities_scalar):
            if cap <= failure_threshold:
                failure_cycle = valid_cycles[i]
                break

        if failure_cycle == -1:
            print(f"{cell_key} didn't reach {failure_threshold} Ah threshold in {len(valid_cycles)} cycles. Using last cycle as proxy.")
            failure_cycle = valid_cycles[-1]
    else:
        print(f"No valid capacity data for {cell_key}. Skipping RUL calculation.")
        failure_cycle = cycles[-1] if cycles else -1

    ruls = [max(0.0, failure_cycle - c) if not np.isnan(cap) else np.nan for c, cap in zip(cycles, capacities)]  # Cap RUL at 0.0

    # Create DataFrame with cycle data
    df_processed = pd.DataFrame({
        'Cycle': cycles,  # Characterization cycle number (e.g., 2, 3, 4 for cyc0100, cyc0200, etc.)
        'Voltage (V)': [v.item() if hasattr(v, 'item') and not np.isnan(v) else v for v in voltages],
        'Current (A)': [c.item() if hasattr(c, 'item') and not np.isnan(c) else c for c in currents],
        'Temperature (°C)': [t.item() if hasattr(t, 'item') and not np.isnan(t) else t for t in temps],
        'Capacity (Ah)': capacities,
        'SoH (%)': soh,
        'RUL (Cycles)': ruls
    })

    # Handle NaN values (e.g., interpolate or drop if needed)
    df_processed = df_processed.interpolate(method='linear').bfill().ffill()

    # Print stats with scalar values
    print(f"\n{cell_key} Stats (Threshold {failure_threshold} Ah, 80% SoH):")
    print(f"Loaded {len(cycles)} characterization cycles.")
    if valid_capacities:
        print(f"Initial capacity: {valid_capacities_scalar[0]:.3f} Ah")
        print(f"Final capacity: {valid_capacities_scalar[-1]:.3f} Ah")
        print(f"Initial SoH: {soh[0]:.1f}%")
        print(f"Final SoH: {soh[-1]:.1f}%")
    else:
        print("No valid capacity data available.")
    if failure_cycle != -1:
        failure_cap = next(cap for cap, cyc in zip(valid_capacities_scalar, valid_cycles) if cyc == failure_cycle)
        failure_soh = next(s for s, c in zip(soh, cycles) if c == failure_cycle and not np.isnan(s))
        print(f"Failure cycle: {failure_cycle} (capacity ~{failure_cap:.3f} Ah, SoH ~{failure_soh:.1f}%)")
    print(f"RUL at cycle 1: {ruls[0] if not np.isnan(ruls[0]) else 'N/A'} cycles")

    # Save DataFrame to CSV
    output_file = f'../data/Oxford/preprocessed/cell{cell_id}_processed.csv'
    df_processed.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}\n")

print("All Oxford cells processed.")
# Out:
# Processing Cell1...
# Found cycle keys: ['cyc0000', 'cyc0100', 'cyc0200', 'cyc0300', 'cyc0400', 'cyc0500', 'cyc0600', 'cyc0700', 'cyc0800', 'cyc0900', 'cyc1000', 'cyc1100', 'cyc1200', 'cyc1300', 'cyc1400', 'cyc1600', 'cyc1800', 'cyc1900', 'cyc2000', 'cyc2100', 'cyc2200', 'cyc2300', 'cyc2400', 'cyc2500', 'cyc2600', 'cyc2700', 'cyc2800', 'cyc2900', 'cyc3000', 'cyc3100', 'cyc3200', 'cyc3300', 'cyc3500', 'cyc3600', 'cyc3700', 'cyc3800', 'cyc3900', 'cyc4000', 'cyc4100', 'cyc4200', 'cyc4300', 'cyc4400', 'cyc4500', 'cyc4600', 'cyc4800', 'cyc5000', 'cyc5100', 'cyc5200', 'cyc5300', 'cyc5400', 'cyc5500', 'cyc5600', 'cyc5700', 'cyc5800', 'cyc5900', 'cyc6000', 'cyc6100', 'cyc6200', 'cyc6300', 'cyc6400', 'cyc6500', 'cyc6600', 'cyc6700', 'cyc6800', 'cyc6900', 'cyc7000', 'cyc7100', 'cyc7200', 'cyc7300', 'cyc7400', 'cyc7500', 'cyc7600', 'cyc7700', 'cyc7800', 'cyc7900', 'cyc8000', 'cyc8100', 'cyc8200']
# Initial capacity for Cell1: 0.739 Ah
#
# Processing cycle cyc0000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-739.11092106], Shape: (1,)
# Charge shape: (3608, 1)
# Time shape: (3608, 1)
# Time values (first 5): [[735954.81722558]
#  [735954.81723716]
#  [735954.81724873]
#  [735954.8172603 ]
#  [735954.81727188]]
# Current lengths - Cycles: 1, Capacities: 1, Voltages: 1, Currents: 1, Temps: 1, SoH: 1
#
# Processing cycle cyc0100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-730.19294941], Shape: (1,)
# Charge shape: (3565, 1)
# Time shape: (3565, 1)
# Time values (first 5): [[735961.98322343]
#  [735961.98323501]
#  [735961.98324658]
#  [735961.98325816]
#  [735961.98326973]]
# Current lengths - Cycles: 2, Capacities: 2, Voltages: 2, Currents: 2, Temps: 2, SoH: 2
#
# Processing cycle cyc0200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-725.7467376], Shape: (1,)
# Charge shape: (3544, 1)
# Time shape: (3544, 1)
# Time values (first 5): [[735969.13711432]
#  [735969.1371259 ]
#  [735969.13713747]
#  [735969.13714904]
#  [735969.13716062]]
# Current lengths - Cycles: 3, Capacities: 3, Voltages: 3, Currents: 3, Temps: 3, SoH: 3
#
# Processing cycle cyc0300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-722.84319732], Shape: (1,)
# Charge shape: (3530, 1)
# Time shape: (3530, 1)
# Time values (first 5): [[735977.7914607 ]
#  [735977.79147228]
#  [735977.79148385]
#  [735977.79149543]
#  [735977.791507  ]]
# Current lengths - Cycles: 4, Capacities: 4, Voltages: 4, Currents: 4, Temps: 4, SoH: 4
#
# Processing cycle cyc0400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-718.36689584], Shape: (1,)
# Charge shape: (3507, 1)
# Time shape: (3507, 1)
# Time values (first 5): [[735984.92767206]
#  [735984.92768364]
#  [735984.92769521]
#  [735984.92770679]
#  [735984.92771836]]
# Current lengths - Cycles: 5, Capacities: 5, Voltages: 5, Currents: 5, Temps: 5, SoH: 5
#
# Processing cycle cyc0500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-714.9787007], Shape: (1,)
# Charge shape: (3491, 1)
# Time shape: (3491, 1)
# Time values (first 5): [[735992.05554543]
#  [735992.055557  ]
#  [735992.05556858]
#  [735992.05558015]
#  [735992.05559173]]
# Current lengths - Cycles: 6, Capacities: 6, Voltages: 6, Currents: 6, Temps: 6, SoH: 6
#
# Processing cycle cyc0600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-711.62040539], Shape: (1,)
# Charge shape: (3475, 1)
# Time shape: (3475, 1)
# Time values (first 5): [[735999.17561175]
#  [735999.17562333]
#  [735999.1756349 ]
#  [735999.17564647]
#  [735999.17565805]]
# Current lengths - Cycles: 7, Capacities: 7, Voltages: 7, Currents: 7, Temps: 7, SoH: 7
#
# Processing cycle cyc0700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-709.53211703], Shape: (1,)
# Charge shape: (3455, 1)
# Time shape: (3455, 1)
# Time values (first 5): [[736006.79131598]
#  [736006.79132755]
#  [736006.79133912]
#  [736006.7913507 ]
#  [736006.79136227]]
# Current lengths - Cycles: 8, Capacities: 8, Voltages: 8, Currents: 8, Temps: 8, SoH: 8
#
# Processing cycle cyc0800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-705.84801114], Shape: (1,)
# Charge shape: (3437, 1)
# Time shape: (3437, 1)
# Time values (first 5): [[736013.90347502]
#  [736013.90348659]
#  [736013.90349816]
#  [736013.90350974]
#  [736013.90352131]]
# Current lengths - Cycles: 9, Capacities: 9, Voltages: 9, Currents: 9, Temps: 9, SoH: 9
#
# Processing cycle cyc0900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-702.54497685], Shape: (1,)
# Charge shape: (3421, 1)
# Time shape: (3421, 1)
# Time values (first 5): [[736021.00864588]
#  [736021.00865746]
#  [736021.00866903]
#  [736021.0086806 ]
#  [736021.00869218]]
# Current lengths - Cycles: 10, Capacities: 10, Voltages: 10, Currents: 10, Temps: 10, SoH: 10
#
# Processing cycle cyc1000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-699.41564775], Shape: (1,)
# Charge shape: (3406, 1)
# Time shape: (3406, 1)
# Time values (first 5): [[736028.10667322]
#  [736028.10668479]
#  [736028.10669637]
#  [736028.10670794]
#  [736028.10671952]]
# Current lengths - Cycles: 11, Capacities: 11, Voltages: 11, Currents: 11, Temps: 11, SoH: 11
#
# Processing cycle cyc1100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-696.28359122], Shape: (1,)
# Charge shape: (3391, 1)
# Time shape: (3391, 1)
# Time values (first 5): [[736035.19790663]
#  [736035.1979182 ]
#  [736035.19792978]
#  [736035.19794135]
#  [736035.19795293]]
# Current lengths - Cycles: 12, Capacities: 12, Voltages: 12, Currents: 12, Temps: 12, SoH: 12
#
# Processing cycle cyc1200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-693.26728543], Shape: (1,)
# Charge shape: (3376, 1)
# Time shape: (3376, 1)
# Time values (first 5): [[736042.28195981]
#  [736042.28197138]
#  [736042.28198295]
#  [736042.28199453]
#  [736042.2820061 ]]
# Current lengths - Cycles: 13, Capacities: 13, Voltages: 13, Currents: 13, Temps: 13, SoH: 13
#
# Processing cycle cyc1300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-690.36879436], Shape: (1,)
# Charge shape: (3362, 1)
# Time shape: (3362, 1)
# Time values (first 5): [[736049.35965918]
#  [736049.35967075]
#  [736049.35968233]
#  [736049.3596939 ]
#  [736049.35970548]]
# Current lengths - Cycles: 14, Capacities: 14, Voltages: 14, Currents: 14, Temps: 14, SoH: 14
#
# Processing cycle cyc1400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-687.61924068], Shape: (1,)
# Charge shape: (3349, 1)
# Time shape: (3349, 1)
# Time values (first 5): [[736056.43086112]
#  [736056.43087269]
#  [736056.43088427]
#  [736056.43089584]
#  [736056.43090742]]
# Current lengths - Cycles: 15, Capacities: 15, Voltages: 15, Currents: 15, Temps: 15, SoH: 15
#
# Processing cycle cyc1600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-681.82631546], Shape: (1,)
# Charge shape: (3320, 1)
# Time shape: (3320, 1)
# Time values (first 5): [[736071.55184498]
#  [736071.55185656]
#  [736071.55186813]
#  [736071.55187971]
#  [736071.55189128]]
# Current lengths - Cycles: 16, Capacities: 16, Voltages: 16, Currents: 16, Temps: 16, SoH: 16
#
# Processing cycle cyc1800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-675.88712703], Shape: (1,)
# Charge shape: (3291, 1)
# Time shape: (3291, 1)
# Time values (first 5): [[736088.75263511]
#  [736088.75264669]
#  [736088.75265826]
#  [736088.75266983]
#  [736088.75268141]]
# Current lengths - Cycles: 17, Capacities: 17, Voltages: 17, Currents: 17, Temps: 17, SoH: 17
#
# Processing cycle cyc1900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-672.74328564], Shape: (1,)
# Charge shape: (3276, 1)
# Time shape: (3276, 1)
# Time values (first 5): [[736096.52805446]
#  [736096.52806603]
#  [736096.52807761]
#  [736096.52808918]
#  [736096.52810075]]
# Current lengths - Cycles: 18, Capacities: 18, Voltages: 18, Currents: 18, Temps: 18, SoH: 18
#
# Processing cycle cyc2000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-669.73179832], Shape: (1,)
# Charge shape: (3262, 1)
# Time shape: (3262, 1)
# Time values (first 5): [[736104.52776552]
#  [736104.52777709]
#  [736104.52778867]
#  [736104.52780024]
#  [736104.52781182]]
# Current lengths - Cycles: 19, Capacities: 19, Voltages: 19, Currents: 19, Temps: 19, SoH: 19
#
# Processing cycle cyc2100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-667.41848294], Shape: (1,)
# Charge shape: (3250, 1)
# Time shape: (3250, 1)
# Time values (first 5): [[736111.57033284]
#  [736111.57034442]
#  [736111.57035599]
#  [736111.57036757]
#  [736111.57037914]]
# Current lengths - Cycles: 20, Capacities: 20, Voltages: 20, Currents: 20, Temps: 20, SoH: 20
#
# Processing cycle cyc2200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-663.95262022], Shape: (1,)
# Charge shape: (3234, 1)
# Time shape: (3234, 1)
# Time values (first 5): [[736119.6526267 ]
#  [736119.65263828]
#  [736119.65264985]
#  [736119.65266142]
#  [736119.652673  ]]
# Current lengths - Cycles: 21, Capacities: 21, Voltages: 21, Currents: 21, Temps: 21, SoH: 21
#
# Processing cycle cyc2300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-661.43960864], Shape: (1,)
# Charge shape: (3221, 1)
# Time shape: (3221, 1)
# Time values (first 5): [[736126.6867315 ]
#  [736126.68674307]
#  [736126.68675465]
#  [736126.68676622]
#  [736126.68677779]]
# Current lengths - Cycles: 22, Capacities: 22, Voltages: 22, Currents: 22, Temps: 22, SoH: 22
#
# Processing cycle cyc2400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-658.23244974], Shape: (1,)
# Charge shape: (3206, 1)
# Time shape: (3206, 1)
# Time values (first 5): [[736134.63838386]
#  [736134.63839543]
#  [736134.63840701]
#  [736134.63841858]
#  [736134.63843015]]
# Current lengths - Cycles: 23, Capacities: 23, Voltages: 23, Currents: 23, Temps: 23, SoH: 23
#
# Processing cycle cyc2500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-656.30196629], Shape: (1,)
# Charge shape: (3196, 1)
# Time shape: (3196, 1)
# Time values (first 5): [[736141.66372986]
#  [736141.66374143]
#  [736141.66375301]
#  [736141.66376458]
#  [736141.66377615]]
# Current lengths - Cycles: 24, Capacities: 24, Voltages: 24, Currents: 24, Temps: 24, SoH: 24
#
# Processing cycle cyc2600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-652.78104527], Shape: (1,)
# Charge shape: (3179, 1)
# Time shape: (3179, 1)
# Time values (first 5): [[736151.83122287]
#  [736151.83123445]
#  [736151.83124602]
#  [736151.83125759]
#  [736151.83126917]]
# Current lengths - Cycles: 25, Capacities: 25, Voltages: 25, Currents: 25, Temps: 25, SoH: 25
#
# Processing cycle cyc2700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-651.2742697], Shape: (1,)
# Charge shape: (3172, 1)
# Time shape: (3172, 1)
# Time values (first 5): [[736158.84753964]
#  [736158.84755121]
#  [736158.84756279]
#  [736158.84757436]
#  [736158.84758593]]
# Current lengths - Cycles: 26, Capacities: 26, Voltages: 26, Currents: 26, Temps: 26, SoH: 26
#
# Processing cycle cyc2800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-648.85010252], Shape: (1,)
# Charge shape: (3160, 1)
# Time shape: (3160, 1)
# Time values (first 5): [[736165.86603785]
#  [736165.86604942]
#  [736165.86606099]
#  [736165.86607257]
#  [736165.86608414]]
# Current lengths - Cycles: 27, Capacities: 27, Voltages: 27, Currents: 27, Temps: 27, SoH: 27
#
# Processing cycle cyc2900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-645.02183976], Shape: (1,)
# Charge shape: (3141, 1)
# Time shape: (3141, 1)
# Time values (first 5): [[736177.7876375 ]
#  [736177.78764908]
#  [736177.78766065]
#  [736177.78767223]
#  [736177.7876838 ]]
# Current lengths - Cycles: 28, Capacities: 28, Voltages: 28, Currents: 28, Temps: 28, SoH: 28
#
# Processing cycle cyc3000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-644.16898476], Shape: (1,)
# Charge shape: (3137, 1)
# Time shape: (3137, 1)
# Time values (first 5): [[736184.79014621]
#  [736184.79015778]
#  [736184.79016936]
#  [736184.79018093]
#  [736184.79019251]]
# Current lengths - Cycles: 29, Capacities: 29, Voltages: 29, Currents: 29, Temps: 29, SoH: 29
#
# Processing cycle cyc3100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-642.08915976], Shape: (1,)
# Charge shape: (3127, 1)
# Time shape: (3127, 1)
# Time values (first 5): [[736191.79610157]
#  [736191.79611314]
#  [736191.79612472]
#  [736191.79613629]
#  [736191.79614786]]
# Current lengths - Cycles: 30, Capacities: 30, Voltages: 30, Currents: 30, Temps: 30, SoH: 30
#
# Processing cycle cyc3200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-638.77292331], Shape: (1,)
# Charge shape: (3111, 1)
# Time shape: (3111, 1)
# Time values (first 5): [[736200.77819831]
#  [736200.77820989]
#  [736200.77822146]
#  [736200.77823304]
#  [736200.77824461]]
# Current lengths - Cycles: 31, Capacities: 31, Voltages: 31, Currents: 31, Temps: 31, SoH: 31
#
# Processing cycle cyc3300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-637.81924416], Shape: (1,)
# Charge shape: (3106, 1)
# Time shape: (3106, 1)
# Time values (first 5): [[736207.76799704]
#  [736207.76800861]
#  [736207.76802019]
#  [736207.76803176]
#  [736207.76804333]]
# Current lengths - Cycles: 32, Capacities: 32, Voltages: 32, Currents: 32, Temps: 32, SoH: 32
#
# Processing cycle cyc3500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-632.20301797], Shape: (1,)
# Charge shape: (3079, 1)
# Time shape: (3079, 1)
# Time values (first 5): [[736223.60321716]
#  [736223.60322873]
#  [736223.6032403 ]
#  [736223.60325188]
#  [736223.60326345]]
# Current lengths - Cycles: 33, Capacities: 33, Voltages: 33, Currents: 33, Temps: 33, SoH: 33
#
# Processing cycle cyc3600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-631.7444982], Shape: (1,)
# Charge shape: (3077, 1)
# Time shape: (3077, 1)
# Time values (first 5): [[736230.57586207]
#  [736230.57587364]
#  [736230.57588522]
#  [736230.57589679]
#  [736230.57590836]]
# Current lengths - Cycles: 34, Capacities: 34, Voltages: 34, Currents: 34, Temps: 34, SoH: 34
#
# Processing cycle cyc3700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-629.52028341], Shape: (1,)
# Charge shape: (3066, 1)
# Time shape: (3066, 1)
# Time values (first 5): [[736237.55709692]
#  [736237.5571085 ]
#  [736237.55712007]
#  [736237.55713165]
#  [736237.55714322]]
# Current lengths - Cycles: 35, Capacities: 35, Voltages: 35, Currents: 35, Temps: 35, SoH: 35
#
# Processing cycle cyc3800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-625.49081683], Shape: (1,)
# Charge shape: (3046, 1)
# Time shape: (3046, 1)
# Time values (first 5): [[736249.7300156 ]
#  [736249.73002718]
#  [736249.73003875]
#  [736249.73005032]
#  [736249.7300619 ]]
# Current lengths - Cycles: 36, Capacities: 36, Voltages: 36, Currents: 36, Temps: 36, SoH: 36
#
# Processing cycle cyc3900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-625.25830883], Shape: (1,)
# Charge shape: (3045, 1)
# Time shape: (3045, 1)
# Time values (first 5): [[736256.69621031]
#  [736256.69622188]
#  [736256.69623346]
#  [736256.69624503]
#  [736256.6962566 ]]
# Current lengths - Cycles: 37, Capacities: 37, Voltages: 37, Currents: 37, Temps: 37, SoH: 37
#
# Processing cycle cyc4000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-623.55316476], Shape: (1,)
# Charge shape: (3037, 1)
# Time shape: (3037, 1)
# Time values (first 5): [[736263.66763155]
#  [736263.66764312]
#  [736263.66765469]
#  [736263.66766627]
#  [736263.66767784]]
# Current lengths - Cycles: 38, Capacities: 38, Voltages: 38, Currents: 38, Temps: 38, SoH: 38
#
# Processing cycle cyc4100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-620.4774482], Shape: (1,)
# Charge shape: (3022, 1)
# Time shape: (3022, 1)
# Time values (first 5): [[736272.45040164]
#  [736272.45041322]
#  [736272.45042479]
#  [736272.45043637]
#  [736272.45044794]]
# Current lengths - Cycles: 39, Capacities: 39, Voltages: 39, Currents: 39, Temps: 39, SoH: 39
#
# Processing cycle cyc4200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-619.51866406], Shape: (1,)
# Charge shape: (3017, 1)
# Time shape: (3017, 1)
# Time values (first 5): [[736279.6484996 ]
#  [736279.64851117]
#  [736279.64852274]
#  [736279.64853432]
#  [736279.64854589]]
# Current lengths - Cycles: 40, Capacities: 40, Voltages: 40, Currents: 40, Temps: 40, SoH: 40
#
# Processing cycle cyc4300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-617.60783185], Shape: (1,)
# Charge shape: (3008, 1)
# Time shape: (3008, 1)
# Time values (first 5): [[736286.60207663]
#  [736286.60208821]
#  [736286.60209978]
#  [736286.60211136]
#  [736286.60212293]]
# Current lengths - Cycles: 41, Capacities: 41, Voltages: 41, Currents: 41, Temps: 41, SoH: 41
#
# Processing cycle cyc4400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-615.72618562], Shape: (1,)
# Charge shape: (2999, 1)
# Time shape: (2999, 1)
# Time values (first 5): [[736293.56011764]
#  [736293.56012921]
#  [736293.56014078]
#  [736293.56015236]
#  [736293.56016393]]
# Current lengths - Cycles: 42, Capacities: 42, Voltages: 42, Currents: 42, Temps: 42, SoH: 42
#
# Processing cycle cyc4500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-612.74444274], Shape: (1,)
# Charge shape: (2984, 1)
# Time shape: (2984, 1)
# Time values (first 5): [[736301.52097218]
#  [736301.52098375]
#  [736301.52099533]
#  [736301.5210069 ]
#  [736301.52101848]]
# Current lengths - Cycles: 43, Capacities: 43, Voltages: 43, Currents: 43, Temps: 43, SoH: 43
#
# Processing cycle cyc4600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-612.34961164], Shape: (1,)
# Charge shape: (2983, 1)
# Time shape: (2983, 1)
# Time values (first 5): [[736308.46432849]
#  [736308.46434006]
#  [736308.46435163]
#  [736308.46436321]
#  [736308.46437478]]
# Current lengths - Cycles: 44, Capacities: 44, Voltages: 44, Currents: 44, Temps: 44, SoH: 44
#
# Processing cycle cyc4800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-608.87684484], Shape: (1,)
# Charge shape: (2966, 1)
# Time shape: (2966, 1)
# Time values (first 5): [[736324.5127193 ]
#  [736324.51273088]
#  [736324.51274245]
#  [736324.51275403]
#  [736324.5127656 ]]
# Current lengths - Cycles: 45, Capacities: 45, Voltages: 45, Currents: 45, Temps: 45, SoH: 45
#
# Processing cycle cyc5000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-604.28694015], Shape: (1,)
# Charge shape: (2944, 1)
# Time shape: (2944, 1)
# Time values (first 5): [[736348.71007514]
#  [736348.71008672]
#  [736348.71009829]
#  [736348.71010986]
#  [736348.71012144]]
# Current lengths - Cycles: 46, Capacities: 46, Voltages: 46, Currents: 46, Temps: 46, SoH: 46
#
# Processing cycle cyc5100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-603.20697632], Shape: (1,)
# Charge shape: (2938, 1)
# Time shape: (2938, 1)
# Time values (first 5): [[736355.60882495]
#  [736355.60883652]
#  [736355.6088481 ]
#  [736355.60885967]
#  [736355.60887124]]
# Current lengths - Cycles: 47, Capacities: 47, Voltages: 47, Currents: 47, Temps: 47, SoH: 47
#
# Processing cycle cyc5200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-599.82390084], Shape: (1,)
# Charge shape: (2922, 1)
# Time shape: (2922, 1)
# Time values (first 5): [[736367.70224683]
#  [736367.70225841]
#  [736367.70226998]
#  [736367.70228156]
#  [736367.70229313]]
# Current lengths - Cycles: 48, Capacities: 48, Voltages: 48, Currents: 48, Temps: 48, SoH: 48
#
# Processing cycle cyc5300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-599.86215349], Shape: (1,)
# Charge shape: (2922, 1)
# Time shape: (2922, 1)
# Time values (first 5): [[736374.58340681]
#  [736374.58341838]
#  [736374.58342996]
#  [736374.58344153]
#  [736374.58345311]]
# Current lengths - Cycles: 49, Capacities: 49, Voltages: 49, Currents: 49, Temps: 49, SoH: 49
#
# Processing cycle cyc5400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-598.1587016], Shape: (1,)
# Charge shape: (2914, 1)
# Time shape: (2914, 1)
# Time values (first 5): [[736381.46195308]
#  [736381.46196465]
#  [736381.46197623]
#  [736381.4619878 ]
#  [736381.46199938]]
# Current lengths - Cycles: 50, Capacities: 50, Voltages: 50, Currents: 50, Temps: 50, SoH: 50
#
# Processing cycle cyc5500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-594.28014845], Shape: (1,)
# Charge shape: (2895, 1)
# Time shape: (2895, 1)
# Time values (first 5): [[736393.99031122]
#  [736393.99032279]
#  [736393.99033437]
#  [736393.99034594]
#  [736393.99035752]]
# Current lengths - Cycles: 51, Capacities: 51, Voltages: 51, Currents: 51, Temps: 51, SoH: 51
#
# Processing cycle cyc5600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-594.46757262], Shape: (1,)
# Charge shape: (2896, 1)
# Time shape: (2896, 1)
# Time values (first 5): [[736400.86110679]
#  [736400.86111837]
#  [736400.86112994]
#  [736400.86114152]
#  [736400.86115309]]
# Current lengths - Cycles: 52, Capacities: 52, Voltages: 52, Currents: 52, Temps: 52, SoH: 52
#
# Processing cycle cyc5700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-592.85735131], Shape: (1,)
# Charge shape: (2888, 1)
# Time shape: (2888, 1)
# Time values (first 5): [[736407.72903212]
#  [736407.72904369]
#  [736407.72905527]
#  [736407.72906684]
#  [736407.72907841]]
# Current lengths - Cycles: 53, Capacities: 53, Voltages: 53, Currents: 53, Temps: 53, SoH: 53
#
# Processing cycle cyc5800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-590.42536704], Shape: (1,)
# Charge shape: (2876, 1)
# Time shape: (2876, 1)
# Time values (first 5): [[736414.79198925]
#  [736414.79200082]
#  [736414.79201239]
#  [736414.79202397]
#  [736414.79203554]]
# Current lengths - Cycles: 54, Capacities: 54, Voltages: 54, Currents: 54, Temps: 54, SoH: 54
#
# Processing cycle cyc5900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-589.44711431], Shape: (1,)
# Charge shape: (2871, 1)
# Time shape: (2871, 1)
# Time values (first 5): [[736421.65348601]
#  [736421.65349759]
#  [736421.65350916]
#  [736421.65352074]
#  [736421.65353231]]
# Current lengths - Cycles: 55, Capacities: 55, Voltages: 55, Currents: 55, Temps: 55, SoH: 55
#
# Processing cycle cyc6000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-588.1173066], Shape: (1,)
# Charge shape: (2865, 1)
# Time shape: (2865, 1)
# Time values (first 5): [[736428.51276083]
#  [736428.5127724 ]
#  [736428.51278397]
#  [736428.51279555]
#  [736428.51280712]]
# Current lengths - Cycles: 56, Capacities: 56, Voltages: 56, Currents: 56, Temps: 56, SoH: 56
#
# Processing cycle cyc6100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-585.56036914], Shape: (1,)
# Charge shape: (2853, 1)
# Time shape: (2853, 1)
# Time values (first 5): [[736436.60120413]
#  [736436.6012157 ]
#  [736436.60122728]
#  [736436.60123885]
#  [736436.60125043]]
# Current lengths - Cycles: 57, Capacities: 57, Voltages: 57, Currents: 57, Temps: 57, SoH: 57
#
# Processing cycle cyc6200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-585.74637946], Shape: (1,)
# Charge shape: (2853, 1)
# Time shape: (2853, 1)
# Time values (first 5): [[736443.45647479]
#  [736443.45648636]
#  [736443.45649794]
#  [736443.45650951]
#  [736443.45652109]]
# Current lengths - Cycles: 58, Capacities: 58, Voltages: 58, Currents: 58, Temps: 58, SoH: 58
#
# Processing cycle cyc6300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-584.15183102], Shape: (1,)
# Charge shape: (2846, 1)
# Time shape: (2846, 1)
# Time values (first 5): [[736450.30880922]
#  [736450.30882079]
#  [736450.30883237]
#  [736450.30884394]
#  [736450.30885552]]
# Current lengths - Cycles: 59, Capacities: 59, Voltages: 59, Currents: 59, Temps: 59, SoH: 59
#
# Processing cycle cyc6400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-581.27576196], Shape: (1,)
# Charge shape: (2831, 1)
# Time shape: (2831, 1)
# Time values (first 5): [[736459.47533543]
#  [736459.475347  ]
#  [736459.47535857]
#  [736459.47537015]
#  [736459.47538172]]
# Current lengths - Cycles: 60, Capacities: 60, Voltages: 60, Currents: 60, Temps: 60, SoH: 60
#
# Processing cycle cyc6500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-581.65477831], Shape: (1,)
# Charge shape: (2834, 1)
# Time shape: (2834, 1)
# Time values (first 5): [[736466.32300692]
#  [736466.3230185 ]
#  [736466.32303007]
#  [736466.32304165]
#  [736466.32305322]]
# Current lengths - Cycles: 61, Capacities: 61, Voltages: 61, Currents: 61, Temps: 61, SoH: 61
#
# Processing cycle cyc6600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-580.03343897], Shape: (1,)
# Charge shape: (2826, 1)
# Time shape: (2826, 1)
# Time values (first 5): [[736473.16701258]
#  [736473.16702415]
#  [736473.16703572]
#  [736473.1670473 ]
#  [736473.16705887]]
# Current lengths - Cycles: 62, Capacities: 62, Voltages: 62, Currents: 62, Temps: 62, SoH: 62
#
# Processing cycle cyc6700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-577.63388019], Shape: (1,)
# Charge shape: (2814, 1)
# Time shape: (2814, 1)
# Time values (first 5): [[736490.48072796]
#  [736490.48073954]
#  [736490.48075111]
#  [736490.48076268]
#  [736490.48077426]]
# Current lengths - Cycles: 63, Capacities: 63, Voltages: 63, Currents: 63, Temps: 63, SoH: 63
#
# Processing cycle cyc6800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-577.58939241], Shape: (1,)
# Charge shape: (2814, 1)
# Time shape: (2814, 1)
# Time values (first 5): [[736497.31768174]
#  [736497.31769331]
#  [736497.31770489]
#  [736497.31771646]
#  [736497.31772804]]
# Current lengths - Cycles: 64, Capacities: 64, Voltages: 64, Currents: 64, Temps: 64, SoH: 64
#
# Processing cycle cyc6900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-576.41677081], Shape: (1,)
# Charge shape: (2808, 1)
# Time shape: (2808, 1)
# Time values (first 5): [[736504.15039367]
#  [736504.15040524]
#  [736504.15041682]
#  [736504.15042839]
#  [736504.15043996]]
# Current lengths - Cycles: 65, Capacities: 65, Voltages: 65, Currents: 65, Temps: 65, SoH: 65
#
# Processing cycle cyc7000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-573.09797896], Shape: (1,)
# Charge shape: (2792, 1)
# Time shape: (2792, 1)
# Time values (first 5): [[736515.69702817]
#  [736515.69703975]
#  [736515.69705132]
#  [736515.69706289]
#  [736515.69707447]]
# Current lengths - Cycles: 66, Capacities: 66, Voltages: 66, Currents: 66, Temps: 66, SoH: 66
#
# Processing cycle cyc7100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-573.09797896], Shape: (1,)
# Charge shape: (2792, 1)
# Time shape: (2792, 1)
# Time values (first 5): [[736515.69702817]
#  [736515.69703975]
#  [736515.69705132]
#  [736515.69706289]
#  [736515.69707447]]
# Current lengths - Cycles: 67, Capacities: 67, Voltages: 67, Currents: 67, Temps: 67, SoH: 67
#
# Processing cycle cyc7200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-574.97146599], Shape: (1,)
# Charge shape: (2801, 1)
# Time shape: (2801, 1)
# Time values (first 5): [[736522.58112242]
#  [736522.581134  ]
#  [736522.58114557]
#  [736522.58115714]
#  [736522.58116872]]
# Current lengths - Cycles: 68, Capacities: 68, Voltages: 68, Currents: 68, Temps: 68, SoH: 68
#
# Processing cycle cyc7300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-572.03756401], Shape: (1,)
# Charge shape: (2787, 1)
# Time shape: (2787, 1)
# Time values (first 5): [[736529.40581828]
#  [736529.40582985]
#  [736529.40584143]
#  [736529.405853  ]
#  [736529.40586457]]
# Current lengths - Cycles: 69, Capacities: 69, Voltages: 69, Currents: 69, Temps: 69, SoH: 69
#
# Processing cycle cyc7400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-570.43658379], Shape: (1,)
# Charge shape: (2779, 1)
# Time shape: (2779, 1)
# Time values (first 5): [[736536.22850208]
#  [736536.22851365]
#  [736536.22852522]
#  [736536.2285368 ]
#  [736536.22854837]]
# Current lengths - Cycles: 70, Capacities: 70, Voltages: 70, Currents: 70, Temps: 70, SoH: 70
#
# Processing cycle cyc7500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-568.26785951], Shape: (1,)
# Charge shape: (2768, 1)
# Time shape: (2768, 1)
# Time values (first 5): [[736543.45633647]
#  [736543.45634804]
#  [736543.45635961]
#  [736543.45637119]
#  [736543.45638276]]
# Current lengths - Cycles: 71, Capacities: 71, Voltages: 71, Currents: 71, Temps: 71, SoH: 71
#
# Processing cycle cyc7600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-567.79291033], Shape: (1,)
# Charge shape: (2766, 1)
# Time shape: (2766, 1)
# Time values (first 5): [[736550.27453928]
#  [736550.27455086]
#  [736550.27456243]
#  [736550.27457401]
#  [736550.27458558]]
# Current lengths - Cycles: 72, Capacities: 72, Voltages: 72, Currents: 72, Temps: 72, SoH: 72
#
# Processing cycle cyc7700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-566.75323093], Shape: (1,)
# Charge shape: (2761, 1)
# Time shape: (2761, 1)
# Time values (first 5): [[736557.0901748 ]
#  [736557.09018638]
#  [736557.09019795]
#  [736557.09020952]
#  [736557.0902211 ]]
# Current lengths - Cycles: 73, Capacities: 73, Voltages: 73, Currents: 73, Temps: 73, SoH: 73
#
# Processing cycle cyc7800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-564.22657246], Shape: (1,)
# Charge shape: (2749, 1)
# Time shape: (2749, 1)
# Time values (first 5): [[736564.67476664]
#  [736564.67477821]
#  [736564.67478979]
#  [736564.67480136]
#  [736564.67481293]]
# Current lengths - Cycles: 74, Capacities: 74, Voltages: 74, Currents: 74, Temps: 74, SoH: 74
#
# Processing cycle cyc7900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-564.31769757], Shape: (1,)
# Charge shape: (2749, 1)
# Time shape: (2749, 1)
# Time values (first 5): [[736571.48767521]
#  [736571.48768679]
#  [736571.48769836]
#  [736571.48770993]
#  [736571.48772151]]
# Current lengths - Cycles: 75, Capacities: 75, Voltages: 75, Currents: 75, Temps: 75, SoH: 75
#
# Processing cycle cyc8000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-563.04645454], Shape: (1,)
# Charge shape: (2743, 1)
# Time shape: (2743, 1)
# Time values (first 5): [[736578.29702618]
#  [736578.29703776]
#  [736578.29704933]
#  [736578.29706091]
#  [736578.29707248]]
# Current lengths - Cycles: 76, Capacities: 76, Voltages: 76, Currents: 76, Temps: 76, SoH: 76
#
# Processing cycle cyc8100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-560.01359691], Shape: (1,)
# Charge shape: (2728, 1)
# Time shape: (2728, 1)
# Time values (first 5): [[736586.62219038]
#  [736586.62220195]
#  [736586.62221353]
#  [736586.6222251 ]
#  [736586.62223667]]
# Current lengths - Cycles: 77, Capacities: 77, Voltages: 77, Currents: 77, Temps: 77, SoH: 77
#
# Processing cycle cyc8200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-560.64958287], Shape: (1,)
# Charge shape: (2732, 1)
# Time shape: (2732, 1)
# Time values (first 5): [[736593.4280845 ]
#  [736593.42809607]
#  [736593.42810765]
#  [736593.42811922]
#  [736593.4281308 ]]
# Current lengths - Cycles: 78, Capacities: 78, Voltages: 78, Currents: 78, Temps: 78, SoH: 78
#
# Cell1 Stats (Threshold 0.592 Ah, 80% SoH):
# Loaded 78 characterization cycles.
# Initial capacity: 0.739 Ah
# Final capacity: 0.561 Ah
# Initial SoH: 100.0%
# Final SoH: 75.9%
# Failure cycle: 59.0 (capacity ~0.590 Ah, SoH ~79.9%)
# RUL at cycle 1: 58.0 cycles
# Data saved to ../data/Oxford/preprocessed/cell1_processed.csv
#
#
# Processing Cell2...
# Found cycle keys: ['cyc0000', 'cyc0100', 'cyc0200', 'cyc0300', 'cyc0400', 'cyc0500', 'cyc0600', 'cyc0700', 'cyc0800', 'cyc0900', 'cyc1000', 'cyc1100', 'cyc1200', 'cyc1300', 'cyc1400', 'cyc1600', 'cyc1800', 'cyc1900', 'cyc2000', 'cyc2100', 'cyc2200', 'cyc2300', 'cyc2400', 'cyc2500', 'cyc2600', 'cyc2700', 'cyc2800', 'cyc2900', 'cyc3000', 'cyc3100', 'cyc3200', 'cyc3300', 'cyc3500', 'cyc3600', 'cyc3700', 'cyc3800', 'cyc3900', 'cyc4000', 'cyc4100', 'cyc4200', 'cyc4300', 'cyc4400', 'cyc4500', 'cyc4600', 'cyc4800', 'cyc5000', 'cyc5100', 'cyc5200', 'cyc5300', 'cyc5400', 'cyc5500', 'cyc5600', 'cyc5700', 'cyc5800', 'cyc5900', 'cyc6000', 'cyc6100', 'cyc6200', 'cyc6300', 'cyc6400', 'cyc6500', 'cyc6600', 'cyc6700', 'cyc6800', 'cyc6900', 'cyc7000', 'cyc7100', 'cyc7200', 'cyc7300', 'cyc7400', 'cyc7500', 'cyc7600', 'cyc7700']
# Initial capacity for Cell2: 0.735 Ah
#
# Processing cycle cyc0000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-734.8189657], Shape: (1,)
# Charge shape: (3578, 1)
# Time shape: (3578, 1)
# Time values (first 5): [[735954.81583877]
#  [735954.81585035]
#  [735954.81586192]
#  [735954.8158735 ]
#  [735954.81588507]]
# Current lengths - Cycles: 1, Capacities: 1, Voltages: 1, Currents: 1, Temps: 1, SoH: 1
#
# Processing cycle cyc0100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-726.62205791], Shape: (1,)
# Charge shape: (3539, 1)
# Time shape: (3539, 1)
# Time values (first 5): [[735961.97825552]
#  [735961.97826709]
#  [735961.97827866]
#  [735961.97829024]
#  [735961.97830181]]
# Current lengths - Cycles: 2, Capacities: 2, Voltages: 2, Currents: 2, Temps: 2, SoH: 2
#
# Processing cycle cyc0200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-722.15714002], Shape: (1,)
# Charge shape: (3517, 1)
# Time shape: (3517, 1)
# Time values (first 5): [[735969.12891431]
#  [735969.12892589]
#  [735969.12893746]
#  [735969.12894903]
#  [735969.12896061]]
# Current lengths - Cycles: 3, Capacities: 3, Voltages: 3, Currents: 3, Temps: 3, SoH: 3
#
# Processing cycle cyc0300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-719.21562], Shape: (1,)
# Charge shape: (3503, 1)
# Time shape: (3503, 1)
# Time values (first 5): [[735977.79260901]
#  [735977.79262058]
#  [735977.79263216]
#  [735977.79264373]
#  [735977.79265531]]
# Current lengths - Cycles: 4, Capacities: 4, Voltages: 4, Currents: 4, Temps: 4, SoH: 4
#
# Processing cycle cyc0400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-714.58230746], Shape: (1,)
# Charge shape: (3480, 1)
# Time shape: (3480, 1)
# Time values (first 5): [[735984.92404126]
#  [735984.92405284]
#  [735984.92406441]
#  [735984.92407598]
#  [735984.92408756]]
# Current lengths - Cycles: 5, Capacities: 5, Voltages: 5, Currents: 5, Temps: 5, SoH: 5
#
# Processing cycle cyc0500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-711.12167583], Shape: (1,)
# Charge shape: (3464, 1)
# Time shape: (3464, 1)
# Time values (first 5): [[735992.0476722 ]
#  [735992.04768378]
#  [735992.04769535]
#  [735992.04770693]
#  [735992.0477185 ]]
# Current lengths - Cycles: 6, Capacities: 6, Voltages: 6, Currents: 6, Temps: 6, SoH: 6
#
# Processing cycle cyc0600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-708.0616104], Shape: (1,)
# Charge shape: (3449, 1)
# Time shape: (3449, 1)
# Time values (first 5): [[735999.16378424]
#  [735999.16379581]
#  [735999.16380739]
#  [735999.16381896]
#  [735999.16383054]]
# Current lengths - Cycles: 7, Capacities: 7, Voltages: 7, Currents: 7, Temps: 7, SoH: 7
#
# Processing cycle cyc0700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-705.45095342], Shape: (1,)
# Charge shape: (3434, 1)
# Time shape: (3434, 1)
# Time values (first 5): [[736006.79183119]
#  [736006.79184276]
#  [736006.79185434]
#  [736006.79186591]
#  [736006.79187748]]
# Current lengths - Cycles: 8, Capacities: 8, Voltages: 8, Currents: 8, Temps: 8, SoH: 8
#
# Processing cycle cyc0800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-701.91023149], Shape: (1,)
# Charge shape: (3417, 1)
# Time shape: (3417, 1)
# Time values (first 5): [[736013.89680771]
#  [736013.89681929]
#  [736013.89683086]
#  [736013.89684244]
#  [736013.89685401]]
# Current lengths - Cycles: 9, Capacities: 9, Voltages: 9, Currents: 9, Temps: 9, SoH: 9
#
# Processing cycle cyc0900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-699.25499035], Shape: (1,)
# Charge shape: (3404, 1)
# Time shape: (3404, 1)
# Time values (first 5): [[736020.99530049]
#  [736020.99531206]
#  [736020.99532364]
#  [736020.99533521]
#  [736020.99534678]]
# Current lengths - Cycles: 10, Capacities: 10, Voltages: 10, Currents: 10, Temps: 10, SoH: 10
#
# Processing cycle cyc1000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-696.66375501], Shape: (1,)
# Charge shape: (3391, 1)
# Time shape: (3391, 1)
# Time values (first 5): [[736028.08779521]
#  [736028.08780679]
#  [736028.08781836]
#  [736028.08782993]
#  [736028.08784151]]
# Current lengths - Cycles: 11, Capacities: 11, Voltages: 11, Currents: 11, Temps: 11, SoH: 11
#
# Processing cycle cyc1100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-693.98479334], Shape: (1,)
# Charge shape: (3378, 1)
# Time shape: (3378, 1)
# Time values (first 5): [[736035.17440266]
#  [736035.17441423]
#  [736035.1744258 ]
#  [736035.17443738]
#  [736035.17444895]]
# Current lengths - Cycles: 12, Capacities: 12, Voltages: 12, Currents: 12, Temps: 12, SoH: 12
#
# Processing cycle cyc1200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-691.20111302], Shape: (1,)
# Charge shape: (3365, 1)
# Time shape: (3365, 1)
# Time values (first 5): [[736042.25510119]
#  [736042.25511276]
#  [736042.25512434]
#  [736042.25513591]
#  [736042.25514748]]
# Current lengths - Cycles: 13, Capacities: 13, Voltages: 13, Currents: 13, Temps: 13, SoH: 13
#
# Processing cycle cyc1300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-688.28244544], Shape: (1,)
# Charge shape: (3351, 1)
# Time shape: (3351, 1)
# Time values (first 5): [[736049.32959608]
#  [736049.32960765]
#  [736049.32961923]
#  [736049.3296308 ]
#  [736049.32964238]]
# Current lengths - Cycles: 14, Capacities: 14, Voltages: 14, Currents: 14, Temps: 14, SoH: 14
#
# Processing cycle cyc1400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-685.44686877], Shape: (1,)
# Charge shape: (3337, 1)
# Time shape: (3337, 1)
# Time values (first 5): [[736056.39799893]
#  [736056.3980105 ]
#  [736056.39802207]
#  [736056.39803365]
#  [736056.39804522]]
# Current lengths - Cycles: 15, Capacities: 15, Voltages: 15, Currents: 15, Temps: 15, SoH: 15
#
# Processing cycle cyc1600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-679.51102141], Shape: (1,)
# Charge shape: (3308, 1)
# Time shape: (3308, 1)
# Time values (first 5): [[736071.5518221 ]
#  [736071.55183367]
#  [736071.55184525]
#  [736071.55185682]
#  [736071.55186839]]
# Current lengths - Cycles: 16, Capacities: 16, Voltages: 16, Currents: 16, Temps: 16, SoH: 16
#
# Processing cycle cyc1800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-674.00544561], Shape: (1,)
# Charge shape: (3281, 1)
# Time shape: (3281, 1)
# Time values (first 5): [[736088.75258447]
#  [736088.75259605]
#  [736088.75260762]
#  [736088.7526192 ]
#  [736088.75263077]]
# Current lengths - Cycles: 17, Capacities: 17, Voltages: 17, Currents: 17, Temps: 17, SoH: 17
#
# Processing cycle cyc1900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-670.64978326], Shape: (1,)
# Charge shape: (3265, 1)
# Time shape: (3265, 1)
# Time values (first 5): [[736096.52803881]
#  [736096.52805039]
#  [736096.52806196]
#  [736096.52807354]
#  [736096.52808511]]
# Current lengths - Cycles: 18, Capacities: 18, Voltages: 18, Currents: 18, Temps: 18, SoH: 18
#
# Processing cycle cyc2000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-667.35258086], Shape: (1,)
# Charge shape: (3249, 1)
# Time shape: (3249, 1)
# Time values (first 5): [[736104.52771682]
#  [736104.52772839]
#  [736104.52773996]
#  [736104.52775154]
#  [736104.52776311]]
# Current lengths - Cycles: 19, Capacities: 19, Voltages: 19, Currents: 19, Temps: 19, SoH: 19
#
# Processing cycle cyc2100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-665.23558768], Shape: (1,)
# Charge shape: (3238, 1)
# Time shape: (3238, 1)
# Time values (first 5): [[736111.57171144]
#  [736111.57172302]
#  [736111.57173459]
#  [736111.57174616]
#  [736111.57175774]]
# Current lengths - Cycles: 20, Capacities: 20, Voltages: 20, Currents: 20, Temps: 20, SoH: 20
#
# Processing cycle cyc2200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-661.54334048], Shape: (1,)
# Charge shape: (3220, 1)
# Time shape: (3220, 1)
# Time values (first 5): [[736119.65263586]
#  [736119.65264744]
#  [736119.65265901]
#  [736119.65267058]
#  [736119.65268216]]
# Current lengths - Cycles: 21, Capacities: 21, Voltages: 21, Currents: 21, Temps: 21, SoH: 21
#
# Processing cycle cyc2300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-659.7519802], Shape: (1,)
# Charge shape: (3212, 1)
# Time shape: (3212, 1)
# Time values (first 5): [[736126.68720679]
#  [736126.68721837]
#  [736126.68722994]
#  [736126.68724151]
#  [736126.68725309]]
# Current lengths - Cycles: 22, Capacities: 22, Voltages: 22, Currents: 22, Temps: 22, SoH: 22
#
# Processing cycle cyc2400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-656.28739141], Shape: (1,)
# Charge shape: (3195, 1)
# Time shape: (3195, 1)
# Time values (first 5): [[736134.63839075]
#  [736134.63840232]
#  [736134.6384139 ]
#  [736134.63842547]
#  [736134.63843705]]
# Current lengths - Cycles: 23, Capacities: 23, Voltages: 23, Currents: 23, Temps: 23, SoH: 23
#
# Processing cycle cyc2500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-654.65010519], Shape: (1,)
# Charge shape: (3187, 1)
# Time shape: (3187, 1)
# Time values (first 5): [[736141.66374294]
#  [736141.66375452]
#  [736141.66376609]
#  [736141.66377767]
#  [736141.66378924]]
# Current lengths - Cycles: 24, Capacities: 24, Voltages: 24, Currents: 24, Temps: 24, SoH: 24
#
# Processing cycle cyc2600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-650.38935286], Shape: (1,)
# Charge shape: (3166, 1)
# Time shape: (3166, 1)
# Time values (first 5): [[736151.83128169]
#  [736151.83129326]
#  [736151.83130484]
#  [736151.83131641]
#  [736151.83132799]]
# Current lengths - Cycles: 25, Capacities: 25, Voltages: 25, Currents: 25, Temps: 25, SoH: 25
#
# Processing cycle cyc2700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-649.66531331], Shape: (1,)
# Charge shape: (3163, 1)
# Time shape: (3163, 1)
# Time values (first 5): [[736158.84707814]
#  [736158.84708971]
#  [736158.84710128]
#  [736158.84711286]
#  [736158.84712443]]
# Current lengths - Cycles: 26, Capacities: 26, Voltages: 26, Currents: 26, Temps: 26, SoH: 26
#
# Processing cycle cyc2800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-647.13291689], Shape: (1,)
# Charge shape: (3150, 1)
# Time shape: (3150, 1)
# Time values (first 5): [[736165.86591705]
#  [736165.86592862]
#  [736165.8659402 ]
#  [736165.86595177]
#  [736165.86596334]]
# Current lengths - Cycles: 27, Capacities: 27, Voltages: 27, Currents: 27, Temps: 27, SoH: 27
#
# Processing cycle cyc2900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-642.13482499], Shape: (1,)
# Charge shape: (3126, 1)
# Time shape: (3126, 1)
# Time values (first 5): [[736177.78768674]
#  [736177.78769831]
#  [736177.78770989]
#  [736177.78772146]
#  [736177.78773304]]
# Current lengths - Cycles: 28, Capacities: 28, Voltages: 28, Currents: 28, Temps: 28, SoH: 28
#
# Processing cycle cyc3000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-641.70528315], Shape: (1,)
# Charge shape: (3124, 1)
# Time shape: (3124, 1)
# Time values (first 5): [[736184.7900718 ]
#  [736184.79008337]
#  [736184.79009494]
#  [736184.79010652]
#  [736184.79011809]]
# ...
#  [736286.60325891]
#  [736286.60327049]
#  [736286.60328206]
#  [736286.60329364]]
# Current lengths - Cycles: 40, Capacities: 40, Voltages: 40, Currents: 40, Temps: 40, SoH: 40
#
# Processing cycle cyc4400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-620.47608645], Shape: (1,)
# Charge shape: (3021, 1)
# Time shape: (3021, 1)
# Time values (first 5): [[736293.56145566]
#  [736293.56146723]
#  [736293.5614788 ]
#  [736293.56149038]
#  [736293.56150195]]
# Current lengths - Cycles: 41, Capacities: 41, Voltages: 41, Currents: 41, Temps: 41, SoH: 41
#
# Processing cycle cyc4500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-616.99837682], Shape: (1,)
# Charge shape: (3004, 1)
# Time shape: (3004, 1)
# Time values (first 5): [[736301.5209044 ]
#  [736301.52091598]
#  [736301.52092755]
#  [736301.52093912]
#  [736301.5209507 ]]
# Current lengths - Cycles: 42, Capacities: 42, Voltages: 42, Currents: 42, Temps: 42, SoH: 42
#
# Processing cycle cyc4600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-616.3392973], Shape: (1,)
# Charge shape: (3001, 1)
# Time shape: (3001, 1)
# Time values (first 5): [[736308.4657835 ]
#  [736308.46579508]
#  [736308.46580665]
#  [736308.46581823]
#  [736308.4658298 ]]
# Current lengths - Cycles: 43, Capacities: 43, Voltages: 43, Currents: 43, Temps: 43, SoH: 43
#
# Processing cycle cyc4800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-612.27327381], Shape: (1,)
# Charge shape: (2981, 1)
# Time shape: (2981, 1)
# Time values (first 5): [[736324.5140478 ]
#  [736324.51405937]
#  [736324.51407094]
#  [736324.51408252]
#  [736324.51409409]]
# Current lengths - Cycles: 44, Capacities: 44, Voltages: 44, Currents: 44, Temps: 44, SoH: 44
#
# Processing cycle cyc5000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-607.32627188], Shape: (1,)
# Charge shape: (2957, 1)
# Time shape: (2957, 1)
# Time values (first 5): [[736348.70998173]
#  [736348.7099933 ]
#  [736348.71000488]
#  [736348.71001645]
#  [736348.71002803]]
# Current lengths - Cycles: 45, Capacities: 45, Voltages: 45, Currents: 45, Temps: 45, SoH: 45
#
# Processing cycle cyc5100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-605.94172564], Shape: (1,)
# Charge shape: (2950, 1)
# Time shape: (2950, 1)
# Time values (first 5): [[736355.61052204]
#  [736355.61053362]
#  [736355.61054519]
#  [736355.61055677]
#  [736355.61056834]]
# Current lengths - Cycles: 46, Capacities: 46, Voltages: 46, Currents: 46, Temps: 46, SoH: 46
#
# Processing cycle cyc5200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-601.89038208], Shape: (1,)
# Charge shape: (2930, 1)
# Time shape: (2930, 1)
# Time values (first 5): [[736367.70232471]
#  [736367.70233628]
#  [736367.70234786]
#  [736367.70235943]
#  [736367.70237101]]
# Current lengths - Cycles: 47, Capacities: 47, Voltages: 47, Currents: 47, Temps: 47, SoH: 47
#
# Processing cycle cyc5300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-601.93478858], Shape: (1,)
# Charge shape: (2931, 1)
# Time shape: (2931, 1)
# Time values (first 5): [[736374.59351741]
#  [736374.59352898]
#  [736374.59354056]
#  [736374.59355213]
#  [736374.5935637 ]]
# Current lengths - Cycles: 48, Capacities: 48, Voltages: 48, Currents: 48, Temps: 48, SoH: 48
#
# Processing cycle cyc5400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-600.00777538], Shape: (1,)
# Charge shape: (2921, 1)
# Time shape: (2921, 1)
# Time values (first 5): [[736381.48173654]
#  [736381.48174811]
#  [736381.48175969]
#  [736381.48177126]
#  [736381.48178283]]
# Current lengths - Cycles: 49, Capacities: 49, Voltages: 49, Currents: 49, Temps: 49, SoH: 49
#
# Processing cycle cyc5500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-596.34903351], Shape: (1,)
# Charge shape: (2904, 1)
# Time shape: (2904, 1)
# Time values (first 5): [[736393.9905073 ]
#  [736393.99051887]
#  [736393.99053045]
#  [736393.99054202]
#  [736393.99055359]]
# Current lengths - Cycles: 50, Capacities: 50, Voltages: 50, Currents: 50, Temps: 50, SoH: 50
#
# Processing cycle cyc5600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-596.22660608], Shape: (1,)
# Charge shape: (2903, 1)
# Time shape: (2903, 1)
# Time values (first 5): [[736400.87125159]
#  [736400.87126316]
#  [736400.87127474]
#  [736400.87128631]
#  [736400.87129788]]
# Current lengths - Cycles: 51, Capacities: 51, Voltages: 51, Currents: 51, Temps: 51, SoH: 51
#
# Processing cycle cyc5700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-594.34096021], Shape: (1,)
# Charge shape: (2894, 1)
# Time shape: (2894, 1)
# Time values (first 5): [[736407.74867566]
#  [736407.74868724]
#  [736407.74869881]
#  [736407.74871039]
#  [736407.74872196]]
# Current lengths - Cycles: 52, Capacities: 52, Voltages: 52, Currents: 52, Temps: 52, SoH: 52
#
# Processing cycle cyc5800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-592.01460018], Shape: (1,)
# Charge shape: (2883, 1)
# Time shape: (2883, 1)
# Time values (first 5): [[736414.79218326]
#  [736414.79219484]
#  [736414.79220641]
#  [736414.79221798]
#  [736414.79222956]]
# Current lengths - Cycles: 53, Capacities: 53, Voltages: 53, Currents: 53, Temps: 53, SoH: 53
#
# Processing cycle cyc5900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-590.48430315], Shape: (1,)
# Charge shape: (2875, 1)
# Time shape: (2875, 1)
# Time values (first 5): [[736421.66308711]
#  [736421.66309868]
#  [736421.66311026]
#  [736421.66312183]
#  [736421.6631334 ]]
# Current lengths - Cycles: 54, Capacities: 54, Voltages: 54, Currents: 54, Temps: 54, SoH: 54
#
# Processing cycle cyc6000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-588.58237644], Shape: (1,)
# Charge shape: (2866, 1)
# Time shape: (2866, 1)
# Time values (first 5): [[736428.53065966]
#  [736428.53067124]
#  [736428.53068281]
#  [736428.53069439]
#  [736428.53070596]]
# Current lengths - Cycles: 55, Capacities: 55, Voltages: 55, Currents: 55, Temps: 55, SoH: 55
#
# Processing cycle cyc6100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-585.28823725], Shape: (1,)
# Charge shape: (2850, 1)
# Time shape: (2850, 1)
# Time values (first 5): [[736436.60101521]
#  [736436.60102678]
#  [736436.60103835]
#  [736436.60104993]
#  [736436.6010615 ]]
# Current lengths - Cycles: 56, Capacities: 56, Voltages: 56, Currents: 56, Temps: 56, SoH: 56
#
# Processing cycle cyc6200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-585.13203873], Shape: (1,)
# Charge shape: (2849, 1)
# Time shape: (2849, 1)
# Time values (first 5): [[736443.46205891]
#  [736443.46207048]
#  [736443.46208206]
#  [736443.46209363]
#  [736443.46210521]]
# Current lengths - Cycles: 57, Capacities: 57, Voltages: 57, Currents: 57, Temps: 57, SoH: 57
#
# Processing cycle cyc6300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-583.22411069], Shape: (1,)
# Charge shape: (2840, 1)
# Time shape: (2840, 1)
# Time values (first 5): [[736450.31917279]
#  [736450.31918436]
#  [736450.31919593]
#  [736450.31920751]
#  [736450.31921908]]
# Current lengths - Cycles: 58, Capacities: 58, Voltages: 58, Currents: 58, Temps: 58, SoH: 58
#
# Processing cycle cyc6400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-579.87098633], Shape: (1,)
# Charge shape: (2824, 1)
# Time shape: (2824, 1)
# Time values (first 5): [[736459.47569889]
#  [736459.47571046]
#  [736459.47572204]
#  [736459.47573361]
#  [736459.47574519]]
# Current lengths - Cycles: 59, Capacities: 59, Voltages: 59, Currents: 59, Temps: 59, SoH: 59
#
# Processing cycle cyc6500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-580.34086855], Shape: (1,)
# Charge shape: (2826, 1)
# Time shape: (2826, 1)
# Time values (first 5): [[736466.32707046]
#  [736466.32708203]
#  [736466.32709361]
#  [736466.32710518]
#  [736466.32711676]]
# Current lengths - Cycles: 60, Capacities: 60, Voltages: 60, Currents: 60, Temps: 60, SoH: 60
#
# Processing cycle cyc6600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-578.55335425], Shape: (1,)
# Charge shape: (2817, 1)
# Time shape: (2817, 1)
# Time values (first 5): [[736473.17424903]
#  [736473.17426061]
#  [736473.17427218]
#  [736473.17428375]
#  [736473.17429533]]
# Current lengths - Cycles: 61, Capacities: 61, Voltages: 61, Currents: 61, Temps: 61, SoH: 61
#
# Processing cycle cyc6700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-578.03452064], Shape: (1,)
# Charge shape: (2815, 1)
# Time shape: (2815, 1)
# Time values (first 5): [[736490.48084925]
#  [736490.48086082]
#  [736490.4808724 ]
#  [736490.48088397]
#  [736490.48089554]]
# Current lengths - Cycles: 62, Capacities: 62, Voltages: 62, Currents: 62, Temps: 62, SoH: 62
#
# Processing cycle cyc6800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-577.71429329], Shape: (1,)
# Charge shape: (2813, 1)
# Time shape: (2813, 1)
# Time values (first 5): [[736497.32245734]
#  [736497.32246891]
#  [736497.32248049]
#  [736497.32249206]
#  [736497.32250364]]
# Current lengths - Cycles: 63, Capacities: 63, Voltages: 63, Currents: 63, Temps: 63, SoH: 63
#
# Processing cycle cyc6900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-576.42012924], Shape: (1,)
# Charge shape: (2807, 1)
# Time shape: (2807, 1)
# Time values (first 5): [[736504.16030658]
#  [736504.16031815]
#  [736504.16032972]
#  [736504.1603413 ]
#  [736504.16035287]]
# Current lengths - Cycles: 64, Capacities: 64, Voltages: 64, Currents: 64, Temps: 64, SoH: 64
#
# Processing cycle cyc7000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-573.02108562], Shape: (1,)
# Charge shape: (2790, 1)
# Time shape: (2790, 1)
# Time values (first 5): [[736515.69723184]
#  [736515.69724342]
#  [736515.69725499]
#  [736515.69726657]
#  [736515.69727814]]
# Current lengths - Cycles: 65, Capacities: 65, Voltages: 65, Currents: 65, Temps: 65, SoH: 65
#
# Processing cycle cyc7100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-574.63464779], Shape: (1,)
# Charge shape: (2798, 1)
# Time shape: (2798, 1)
# Time values (first 5): [[736522.58552339]
#  [736522.58553496]
#  [736522.58554653]
#  [736522.58555811]
#  [736522.58556968]]
# Current lengths - Cycles: 66, Capacities: 66, Voltages: 66, Currents: 66, Temps: 66, SoH: 66
#
# Processing cycle cyc7200...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-571.45236313], Shape: (1,)
# Charge shape: (2783, 1)
# Time shape: (2783, 1)
# Time values (first 5): [[736529.41527214]
#  [736529.41528371]
#  [736529.41529528]
#  [736529.41530686]
#  [736529.41531843]]
# Current lengths - Cycles: 67, Capacities: 67, Voltages: 67, Currents: 67, Temps: 67, SoH: 67
#
# Processing cycle cyc7300...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-569.80820299], Shape: (1,)
# Charge shape: (2775, 1)
# Time shape: (2775, 1)
# Time values (first 5): [[736536.24173935]
#  [736536.24175092]
#  [736536.2417625 ]
#  [736536.24177407]
#  [736536.24178565]]
# Current lengths - Cycles: 68, Capacities: 68, Voltages: 68, Currents: 68, Temps: 68, SoH: 68
#
# Processing cycle cyc7400...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-567.56626228], Shape: (1,)
# Charge shape: (2764, 1)
# Time shape: (2764, 1)
# Time values (first 5): [[736543.45643289]
#  [736543.45644447]
#  [736543.45645604]
#  [736543.45646762]
#  [736543.45647919]]
# Current lengths - Cycles: 69, Capacities: 69, Voltages: 69, Currents: 69, Temps: 69, SoH: 69
#
# Processing cycle cyc7500...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-566.65730763], Shape: (1,)
# Charge shape: (2759, 1)
# Time shape: (2759, 1)
# Time values (first 5): [[736550.2789601 ]
#  [736550.27897167]
#  [736550.27898325]
#  [736550.27899482]
#  [736550.2790064 ]]
# Current lengths - Cycles: 70, Capacities: 70, Voltages: 70, Currents: 70, Temps: 70, SoH: 70
#
# Processing cycle cyc7600...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-565.36374679], Shape: (1,)
# Charge shape: (2753, 1)
# Time shape: (2753, 1)
# Time values (first 5): [[736557.09854241]
#  [736557.09855398]
#  [736557.09856555]
#  [736557.09857713]
#  [736557.0985887 ]]
# Current lengths - Cycles: 71, Capacities: 71, Voltages: 71, Currents: 71, Temps: 71, SoH: 71
#
# Processing cycle cyc7700...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-562.96710933], Shape: (1,)
# Charge shape: (2741, 1)
# Time shape: (2741, 1)
# Time values (first 5): [[736564.67507381]
#  [736564.67508538]
#  [736564.67509696]
#  [736564.67510853]
#  [736564.6751201 ]]
# Current lengths - Cycles: 72, Capacities: 72, Voltages: 72, Currents: 72, Temps: 72, SoH: 72
#
# Processing cycle cyc7800...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-562.60049744], Shape: (1,)
# Charge shape: (2740, 1)
# Time shape: (2740, 1)
# Time values (first 5): [[736571.49099483]
#  [736571.49100641]
#  [736571.49101798]
#  [736571.49102955]
#  [736571.49104113]]
# Current lengths - Cycles: 73, Capacities: 73, Voltages: 73, Currents: 73, Temps: 73, SoH: 73
#
# Processing cycle cyc7900...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-561.11114789], Shape: (1,)
# Charge shape: (2732, 1)
# Time shape: (2732, 1)
# Time values (first 5): [[736578.30307025]
#  [736578.30308182]
#  [736578.3030934 ]
#  [736578.30310497]
#  [736578.30311655]]
# Current lengths - Cycles: 74, Capacities: 74, Voltages: 74, Currents: 74, Temps: 74, SoH: 74
#
# Processing cycle cyc8000...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-558.16108357], Shape: (1,)
# Charge shape: (2718, 1)
# Time shape: (2718, 1)
# Time values (first 5): [[736586.62252164]
#  [736586.62253321]
#  [736586.62254479]
#  [736586.62255636]
#  [736586.62256793]]
# Current lengths - Cycles: 75, Capacities: 75, Voltages: 75, Currents: 75, Temps: 75, SoH: 75
#
# Processing cycle cyc8100...
# Cycle data keys: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Discharge data keys: ('t', 'v', 'q', 'T')
# Raw capacity (mAh): [-558.95814042], Shape: (1,)
# Charge shape: (2722, 1)
# Time shape: (2722, 1)
# Time values (first 5): [[736593.43180479]
#  [736593.43181636]
#  [736593.43182793]
#  [736593.43183951]
#  [736593.43185108]]
# Current lengths - Cycles: 76, Capacities: 76, Voltages: 76, Currents: 76, Temps: 76, SoH: 76
#
# Cell8 Stats (Threshold 0.592 Ah, 80% SoH):
# Loaded 76 characterization cycles.
# Initial capacity: 0.728 Ah
# Final capacity: 0.559 Ah
# Initial SoH: 100.0%
# Final SoH: 76.8%
# Failure cycle: 60.0 (capacity ~0.590 Ah, SoH ~81.2%)
# RUL at cycle 1: 59.0 cycles
# Data saved to ../data/Oxford/preprocessed/cell8_processed.csv
#
# All Oxford cells processed.
